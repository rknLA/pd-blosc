# %% [markdown]
# iPython port of [the MinBLEP generator from experimentalscene](http://www.experimentalscene.com/articles/minbleps.php)
#
# Using numpy where possible.
#
# Currently a work in progress.
#
# TODO
# - Implement RealCepstrum, Minimum Phase, integrate, and normalize
# - Integrate the helper functions into the proper `generate_minblep` top-level

# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def blackman_window(length):
    for i in range(0, length):
        f1 = 2.0 * pi * i / length
        f2 = 2.0 * f1
        val = 0.42 - (0.5 * cos(f1)) + (0.08 * cos(f2))
        yield val

# %%
plot(list(blackman_window(200)))

# %%
def sinc_buffer(size, zero_crossings=10):
    for i in range(0, size):
        r = float(i) / (float(size) - 1.0)
        yield sinc(-zero_crossings + (r * 2.0 * zero_crossings))

# %%
plot(list(sinc_buffer(200)))

# %%
plot(list(sinc_buffer(200, 5)))
